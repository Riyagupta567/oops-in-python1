# %% [markdown]
# ### ***OPPs in Python***

# %% [markdown]
# *`Python Work with`*
#
#
# 1.   Object Oriented Programming
# 1.   Functional Programming
# 2.   Procedure Oriented Programmin

# %% [markdown]
# *Simple Class Creation*

# %%
class computer:                                       #class name
  def config(self):                                   #Mentod of class
    print("We are going to learn about OOPs")

comp1=computer()                                      #object of class computer
comp1.config()
# Out:
# We are going to learn about OOPs

# %% [markdown]
# *what is Class?*
#
#
#
# ```
# Class is a Bluerint of  object That contain attribute and behaviour
# ```

# %%
# class with constructor

class A:
  def __init__(self,fname,lname,Salary):          #constructor
    self.fname=fname
    self.lname=lname
    self.Salary=Salary
  def info(self):
    print(f"Name of the person {self.fname+self.lname}")
    print(f"Salary of person is {self.Salary }")

# %% [markdown]
# *Object*
#
# ```
# A Object is a Basic building block of OOPs. It is a real time intity that consist some behaviour and Attribute.
# ```
# ```
# It is instance of a Class and you can create many object of same class
# ```

# %%
person1=A("Riya", "Kumari",100000)  #person1 is a object
person2=A("Nitya","Gupta",200000)
person1.info()
person2.info()
# Out:
# Name of the person RiyaKumari
# Salary of person is 100000
# Name of the person NityaGupta
# Salary of person is 200000

# %% [markdown]
# If you want to chnage value of object variable you can

# %%
person1.fname="Priya"
person1.info()
# Out:
# Name of the person PriyaKumari
# Salary of person is 100000

# %% [markdown]
# *variable *
#
#
# ```
#  in OPPs we see two kind of variable
# 1.   instance Variable
# 2.   class variable
#
#
# ```

# %%
class B:
  Slryincrement=1.8      #class variable
  def __init__(self, Dept, jobid, Salary ):
    self.Dept= Dept
    self.jobid=jobid
    self.Salary=Salary
    self.Slryincrement=1.5     #instance variable

  def incrementclass(self):
    self.Salary=self.Salary*B.Slryincrement

  def incrementnormal(self):
    self.Salary=self.Salary*self.Slryincrement




emp3=B("Tech","azb72",100000)
emp4=B("Tech","axy71",100000)
emp3.incrementclass()
emp4.incrementnormal()
print(emp3.Salary)
print(emp4.Salary)
# Out:
# 180000.0
# 150000.0

# %% [markdown]
# ***Type of Method in Class***
#
# ```
# 1.   Instant Method
# 2.   Class Method
# 3.   Static Method
#
# ```

# %%
#Instant Method
class C:
  def __init__(self, phone, email):
    self.phone=phone
    self.email=email
  def show(self):                                            #instant Method
    print(f"Phone number of person{self.phone}")
    print(f"Email of the person is {self.email}")
  def set_phone(self, Value):                                #Mutator Method:-only for set value
    self.phone=Value
  def get_phone(self,Value):                                 #Accessor Method:- Only for get value
    return self.phone


per4=C("7283032588","aec.cse.riyakumari@gmail.com")
per4.show()
per4.set_phone("8340445078")
per4.show()
# Out:
# Phone number of person7283032588
# Email of the person is aec.cse.riyakumari@gmail.com
# Phone number of person8340445078
# Email of the person is aec.cse.riyakumari@gmail.com

# %%
#class Method
class C:
  def __init__(self, code, id):
    self.code=code
    self.id=id
  def show1(self):
    print(f"Phone number of person{self.code}")
    print(f"Email of the person is {self.id}")
  @classmethod
  def fromstr(cls):
    print("Hiii")


per9=C(123, 1234)
C.fromstr()
# Out:
# Hiii

# %% [markdown]
# **NOTE**
#
# Class method is bounded to a class or rather then a object.
# It can be called by both class and object. We use cls instend of self because
# here we take whole class as a argument.

# %%
#Static Method

class animal:
  def __init__(self,Gender):
    self.Gender=Gender

  @staticmethod
  def Check(gens):
    if gens=="male":
      print("boy")
    else:
      print("girl")
var1=animal("male")
animal.Check("male")
var1.Check("male")
# Out:
# boy
# boy

# %% [markdown]
# **Note**
#
#
# *   A static method is method in class that doesn't need implicit first argument i.e (self)
# *   This method is  access with help of class and object both but you cannot change anything in class state

# %% [markdown]
# **Class method vs Static Method**
#
# *   A class method takes cls as the first parameter while a static method needs no specific parameters.
# *   A class method can access or modify the class state while a static method can’t access or modify it.
# *   In general, static methods know nothing about the class state. They are utility-type methods that take some parameters and work upon those parameters. On the other hand class methods must have class as a parameter.
# *   We use @classmethod decorator in python to create a class method and we use @staticmethod decorator to create a static method in python.

# %% [markdown]
# ***Inner Class***
#
# * A class define inside a class is known as inner class or nested class
# * if a object is created using child class can be use by parent class or a root class
# * Rule for creating subclass
#
#                   *   First we create class and its constructor and inside that constructor we crate object of inner class
#                   *   The class inside the another class will be  inner class

# %%
class D:
  def __init__(self):
    self.lap=self.laptop
  def pyar(self):
    print("I LOVE YOU")

  class laptop:
    def show(self):
      print("Hii i am inner class")

objineer=D.laptop()           #inner class Object
objineer.show()

obj1=D()
obj1.pyar()
# Out:
# Hii i am inner class
# I LOVE YOU
